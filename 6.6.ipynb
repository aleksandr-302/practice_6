# %%
def is_anagram(word1, word2):
  

  x=word1.replace(' ','')
  y=x.lower()
  word1 = sorted(y)


  e=word2.replace(' ','')
  g=e.lower()
  word2 = sorted(g)
  
 
  if word1 == word2:
    print("Являются анаграмами")
  else:
    print("Не являются анаграмами")
is_anagram('Пила', 'Липа')
# Out:
# Являются анаграмами
